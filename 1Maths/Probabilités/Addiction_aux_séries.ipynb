# %% [markdown]
# **Partie 2**
#
# Pour pouvoir utiliser les fonctionnalités de tirage aléatoire, nous avons besoin d'importer la librairie `random`.
#
# `random()` renvoie un nombre décimal entre 0 et 1.
#
# `randint(a,b)` renvoie un nombre entier aléatoire dans [a;b].
#
# Cliquez sur Exécuter pour interpréter l'import de ces fonctions :

# %%
from random import *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Complétez la fonction suivante en utilisant les probabilités ci-dessus puis cliquez sur Exécuter pour interpréter le programme.
#
# `n` est le nombre de journées

# %%
def simule(n):
  PasDeSerie=0
  for i in range(0,...):
    M=...
    S=...
    midi=0
    soir=0
    if M<...:
      midi=1
    if midi==1:
      if S<...:
        soir=1
    else:
      if S<...:
        soir=1
    if midi==... and soir==...:
      PasDeSerie = PasDeSerie+1
  return PasDeSerie/n

# %% [markdown]
# Appelez la fonction précédente pour 10000 semaines :

# %%
simule(...)

# %% [markdown]
# C'est presque terminé. Utilisez "File > Download as Python" pour m'envoyer votre fichier complété sur le cahier de textes.
