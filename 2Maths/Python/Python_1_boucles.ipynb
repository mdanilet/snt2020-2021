# %% [markdown]
# ### **A la fin du TP, enregistrez ce script grâce à la fonction "fichier exporter comme script exécutable" ou "file export as executable script". Pour exécuter un script, utilisez la flèche ou RUN ou EXECUTER**
#
#
# ---

# %% [markdown]
# # Boucles bornées
# Tu as décidé de participer tous les jours de la semaine en classe. Tu obtiens donc 100 XP supplémentaires par jour pendant 7 jours. On souhaite calculer les points d'xp à la fin de la semaine.
# En Scratch :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En Python, répéter 10 fois s'écrit :
#
# ```
# for i in range(10):
#   <instructions>
# ```
#
# Modifie le programme ci-dessous pour simuler la situation ci-dessus (100 XP par jour pendant 7 jours en plus) et affiche le nombre de points d'xp final.

# %%
points_xp=550

# %% [markdown]
# # Boucles non bornées
# Tu décides maintenant que tu vas participer jusqu'à ce que tu obtiennes au moins 5000 XP.
# Voici 2 programmes équivalents en Scratch et en Python :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ma_variable=0
while ma_variable <= 100 :
  #attention, on réitère tant que ça ne dépasse pas alors qu'en Scratch on attend de dépasser !
  ma_variable = ma_variable + 15

# %% [markdown]
# Modifie le programme ci-dessous pour refléter la situation : participer jusqu'à obtenir au moins 5000 XP.

# %%
points_xp = 550
