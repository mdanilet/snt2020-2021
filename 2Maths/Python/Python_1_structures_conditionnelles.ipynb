# %% [markdown]
# ### **A la fin du TP, enregistrez ce script grâce à la fonction "fichier exporter comme script exécutable" ou "file export as executable script". Pour exécuter un script, utilisez la flèche ou RUN ou EXECUTER**
#
# ---

# %% [markdown]
# # Structures conditionnelles
# Le "`Si <condition> Alors <instructions> Sinon <instructions>`" se traduit en Python par :
# ```
# if <condition> :
#   <instructions>
# else :
#   <instructions>
# ```
#
# On souhaite maintenant afficher le niveau du personnage, sachant qu'il est de niveau 1 s'il a moins de 1000 XP, de niveau 2 sinon. Modifiez le programme ci-dessous.
# Si besoin, script Scratch :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
points_xp = randint(50,2000)
if ... :
  ...
else ... :
  ...
print(niveau)
