# %% [markdown]
# # Calcul de la distance entre 2 points dans un repère orthonormé #
# ## Partie Mathématique
# Rappel de la formule de cours : $AB^2=(x_B-x_A)^2+(y_B-y_A)^2$
# ## En Python
# On avait déjà implémenté une fonction ```milieu```.
# On va définir une fonction qui prend en paramètres 2 couples de coordonnées : ```distance(A,B)``` et qui va renvoyer la distance entre ces deux points.
#
# ```A[0]``` renvoie la 1ère coordonnée du point A
#
# Modifiez la formule de distance pour qu'elle soit correcte puis cliquez sur la flèche sur la gauche pour l'interpréter :

# %%
from math import sqrt
def milieu(A,B):
  return ((A[0]+B[0])/2,(A[1]+B[1])/2)
def distance(A,B):
  return sqrt((B[0]-A[0])**2+...)

# %% [markdown]
# On teste la fonction en faisant un appel tout simple : (cliquez sur la flèche pour interpréter)

# %%
A=(2,3)
B=(10,20)
print(milieu(A,B))
print(distance(A,B))

# %% [markdown]
# On souhaite résoudre cet exercice :
# ![82789-1[1].gif](data:image/gif;base64,...)

# %% [markdown]
# Ecrivez un programme en Python utilisant les fonctions précédemment implémentées pour résoudre l'exercice. On pourra utiliser l'instruction
#
# ```
# if condition :
#   #code si la condition est vraie
# else :
#   #code si la confition est fausse
# ```

# %%
A=(-2,1)
B=(2,3)
C=(-3,3)

# %% [markdown]
# Voici un 2ème exercice à résoudre en utilisant les fonctions précédemment implémentées :
# ![82794-1[1].gif](data:image/gif;base64,...)

# %%
A=(5,1)
B=(-1,5)
C=(1,8)
D=(7,4)
