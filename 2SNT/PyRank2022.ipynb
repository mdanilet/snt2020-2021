# %% [markdown]
# ### PY RANK
# Objectif : simuler le surf aléatoire sur un réseau avec Python.
#
# On considère un ensemble de 3 sites web ayant des liens entre eux. Par exemple, la flèche de P1 vers P3 signifie qu'il y a un lien d'une page du site P1 vers une page du site P3.
#
# On considère un surfeur aléatoire qui est actif sur ce réseau. L'exercice doit répondre à la question : A quelle fréquence est-il sur chacun de ces sites ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Importez la fonction de tirage aléatoire : `from random import randint`.
#
# 2. Programmez une fonction `pagesuiv1(pa)` qui tire aléatoirement la page suivante lorsque le surfeur est sur le sommet pa du graphe.
# > On utilisera l'instruction conditionnelle `if ... else ...` et `randint(min,max)`. Par exemple, pour simuler le tirage d'un dé classique équilibré, on utiliserait `randint(1,6)`.
#
# 3. Programmez une fonction `rep(n)` où n est le nombre de répétitions de saut d'un sommet à l'autre et qui retourne les fréquences de passage sur chaque sommet.
#
# Aides sur https://view.genial.ly/5fe1a8d9fa68050cfca3f239 séance "Py Rank".

# %%
from random import randint
def pagesuiv1(pa):

def rep(n):
